# %%
from keras_segmentation.models.unet import resnet50_unet

model = resnet50_unet(n_classes=7 ,  input_height=352 , input_width=288  )

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="-1"    
import tensorflow as tf

# %%
model.train(
    verify_dataset=False,
    train_images =  "tmp/test/",
    train_annotations = "tmp/label/",
    checkpoints_path = "/tmp/resnet50_unet_1" , epochs=4  
)
# Out:
# Epoch 1/4
# 512/512 [==============================] - 639s 1s/step - loss: 0.5674 - accuracy: 0.8934
#
# Epoch 00001: saving model to /tmp/resnet50_unet_1.00001
# Epoch 2/4
# 512/512 [==============================] - 632s 1s/step - loss: 0.0022 - accuracy: 0.9998
#
# Epoch 00002: saving model to /tmp/resnet50_unet_1.00002
# Epoch 3/4
# 512/512 [==============================] - 631s 1s/step - loss: 0.0017 - accuracy: 0.9998
#
# Epoch 00003: saving model to /tmp/resnet50_unet_1.00003
# Epoch 4/4
# 512/512 [==============================] - 630s 1s/step - loss: 0.0011 - accuracy: 0.9998
#
# Epoch 00004: saving model to /tmp/resnet50_unet_1.00004

# %%
out = model.predict_segmentation(
    inp="tmp/test/image6.png",
    out_fname="/tmp/out.png"
)

# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt

# %%
plt.imshow(out)

# %%
from IPython.display import Image
Image('/tmp/out.png')

# %%
o = model.predict_segmentation(
    inp="tmp/test/image6.png",
    out_fname="/tmp/out.png" , overlay_img=True, show_legends=True,
    class_names = ['background', 'Biker', 'Pedestrian', 'Skateboarder', 'Cart', 'Car', 'Bus']

)

# %%
from IPython.display import Image
Image('/tmp/out.png')
